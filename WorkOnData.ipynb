# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-Miri/WorkOnData/blob/main/WorkOnData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Work On Data ###

# %%
# !git clone https://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@github.com/Mahdi-Miri/WorkOnData.git
# Out:
# Cloning into 'WorkOnData'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (9/9), 13.99 KiB | 4.66 MiB/s, done.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {'Stock' : ['AAPL','GOOGL','MSFT'],'Price':[140,4332,123.34],'Volume':[10000,23444,210000]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Stock    Price  Volume
# 0   AAPL   140.00   10000
# 1  GOOGL  4332.00   23444
# 2   MSFT   123.34  210000

# %%
market_df = pd.read_csv('/content/WorkOnData/BTC-USD.csv')

# %%
market_df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2023-08-04  29174.382813  29302.078125  28885.335938  29074.091797
# 1    2023-08-05  29075.388672  29102.464844  28957.796875  29042.126953
# 2    2023-08-06  29043.701172  29160.822266  28963.833984  29041.855469
# 3    2023-08-07  29038.513672  29244.281250  28724.140625  29180.578125
# 4    2023-08-08  29180.019531  30176.796875  29113.814453  29765.492188
# ..          ...           ...           ...           ...           ...
# 362  2024-07-31  66201.273438  66810.210938  64532.046875  64619.250000
# 363  2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 364  2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 365  2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 366  2024-08-04  60676.175781  61042.875000  60171.683594  60407.785156
#
#         Adj Close       Volume
# 0    29074.091797  12036639988
# 1    29042.126953   6598366353
# ...

# %%
print(f"shape of the DataFrame: {market_df.shape}")
# Out:
# shape of the DataFrame: (367, 7)

# %%
print('basic Statistics :')
print(market_df.describe())
# Out:
# basic Statistics :
#                Open          High           Low         Close     Adj Close  \
# count    367.000000    367.000000    367.000000    367.000000    367.000000
# mean   48827.240213  49754.459953  47904.182343  48912.975003  48912.975003
# std    15922.682412  16296.055980  15448.355626  15901.788230  15901.788230
# min    25160.658203  25858.375000  24930.296875  25162.654297  25162.654297
# 25%    34993.630860  35313.183594  34473.695312  35043.363282  35043.363282
# 50%    44332.125000  45899.707031  43662.230469  44957.968750  44957.968750
# 75%    64811.203125  66257.304688  63176.599610  64849.404297  64849.404297
# max    73079.375000  73750.070313  71334.093750  73083.500000  73083.500000
#
#              Volume
# count  3.670000e+02
# mean   2.537049e+10
# std    1.406217e+10
# min    5.331173e+09
# 25%    1.470112e+10
# 50%    2.250600e+10
# 75%    3.261844e+10
# max    1.028029e+11

# %%
print('column name:')
print(market_df.columns)
# Out:
# column name:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       367 non-null    object
#  1   Open       367 non-null    float64
#  2   High       367 non-null    float64
#  3   Low        367 non-null    float64
#  4   Close      367 non-null    float64
#  5   Adj Close  367 non-null    float64
#  6   Volume     367 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 20.2+ KB

# %%
sns.heatmap(market_df.isnull(), cbar=False, yticklabels=False)
# Out:
# <Axes: >

# %%
market_df.isnull()
# Out:
#       Date   Open   High    Low  Close  Adj Close  Volume
# 0    False  False  False  False  False      False   False
# 1    False  False  False  False  False      False   False
# 2    False  False  False  False  False      False   False
# 3    False  False  False  False  False      False   False
# 4    False  False  False  False  False      False   False
# ..     ...    ...    ...    ...    ...        ...     ...
# 362  False  False  False  False  False      False   False
# 363  False  False  False  False  False      False   False
# 364  False  False  False  False  False      False   False
# 365  False  False  False  False  False      False   False
# 366  False  False  False  False  False      False   False
#
# [367 rows x 7 columns]

# %%
market_df['Date'] = pd.to_datetime(market_df['Date'])

# %%
market_df['Date']
# Out:
# 0     2023-08-04
# 1     2023-08-05
# 2     2023-08-06
# 3     2023-08-07
# 4     2023-08-08
#          ...
# 362   2024-07-31
# 363   2024-08-01
# 364   2024-08-02
# 365   2024-08-03
# 366   2024-08-04
# Name: Date, Length: 367, dtype: datetime64[ns]

# %%
market_df.head(5)
# Out:
#         Date          Open          High           Low         Close  \
# 0 2023-08-04  29174.382813  29302.078125  28885.335938  29074.091797
# 1 2023-08-05  29075.388672  29102.464844  28957.796875  29042.126953
# 2 2023-08-06  29043.701172  29160.822266  28963.833984  29041.855469
# 3 2023-08-07  29038.513672  29244.281250  28724.140625  29180.578125
# 4 2023-08-08  29180.019531  30176.796875  29113.814453  29765.492188
#
#       Adj Close       Volume
# 0  29074.091797  12036639988
# 1  29042.126953   6598366353
# 2  29041.855469   7269806994
# 3  29180.578125  13618163710
# 4  29765.492188  17570561357

# %%
plt.bar(market_df['Date'], height = market_df['Close'])
plt.show()

# %%
high_price = market_df[market_df['Close'] > 25000]
print(high_price)
# Out:
#           Date          Open          High           Low         Close  \
# 0   2023-08-04  29174.382813  29302.078125  28885.335938  29074.091797
# 1   2023-08-05  29075.388672  29102.464844  28957.796875  29042.126953
# 2   2023-08-06  29043.701172  29160.822266  28963.833984  29041.855469
# 3   2023-08-07  29038.513672  29244.281250  28724.140625  29180.578125
# 4   2023-08-08  29180.019531  30176.796875  29113.814453  29765.492188
# ..         ...           ...           ...           ...           ...
# 362 2024-07-31  66201.273438  66810.210938  64532.046875  64619.250000
# 363 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 364 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 365 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 366 2024-08-04  60676.175781  61042.875000  60171.683594  60407.785156
#
#         Adj Close       Volume
# 0    29074.091797  12036639988
# 1    29042.126953   6598366353
# ...

# %%
mean_price = market_df['Adj Close'].mean()

# %%
market_df['Adj Close'].min()
# Out:
# 25162.654297

# %%
market_df['Adj Close'].median()
# Out:
# 44957.96875

# %%
market_df['Adj Close'].max()
# Out:
# 73083.5

# %%
 plt.hist(market_df['Close'],bins=60,alpha = 0.7 , color='red', label='Price')
# Out:
# (array([11., 28., 14.,  8.,  7., 11.,  1.,  0.,  0.,  1.,  2.,  7.,  7.,
#          3.,  6., 13.,  1.,  2.,  4.,  0., 10., 15., 16., 16.,  1.,  1.,
#          3.,  2.,  2.,  0.,  1.,  1.,  2., 10.,  0.,  0.,  1.,  0.,  1.,
#          4.,  3.,  3.,  2.,  2.,  9.,  8.,  7., 10., 16.,  7., 10., 11.,
#         12., 13., 12., 13.,  7.,  7.,  2.,  1.]),
#  array([25162.654297  , 25961.33505872, 26760.01582043, 27558.69658215,
#         28357.37734387, 29156.05810558, 29954.7388673 , 30753.41962902,
#         31552.10039073, 32350.78115245, 33149.46191417, 33948.14267588,
#         34746.8234376 , 35545.50419932, 36344.18496103, 37142.86572275,
#         37941.54648447, 38740.22724618, 39538.9080079 , 40337.58876962,
#         41136.26953133, 41934.95029305, 42733.63105477, 43532.31181648,
#         44330.9925782 , 45129.67333992, 45928.35410163, 46727.03486335,
#         47525.71562507, 48324.39638678, 49123.0771485 , 49921.75791022,
# ...

# %%
plt.axvline(mean_price , linestyle = 'dashed')

# %%
market_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
market_df['Price'] = abs(market_df['Close'] - market_df['Open']  )

# %%
market_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Price'], dtype='object')

# %%
market_df.head(5)
# Out:
#         Date          Open          High           Low         Close  \
# 0 2023-08-04  29174.382813  29302.078125  28885.335938  29074.091797
# 1 2023-08-05  29075.388672  29102.464844  28957.796875  29042.126953
# 2 2023-08-06  29043.701172  29160.822266  28963.833984  29041.855469
# 3 2023-08-07  29038.513672  29244.281250  28724.140625  29180.578125
# 4 2023-08-08  29180.019531  30176.796875  29113.814453  29765.492188
#
#       Adj Close       Volume       Price
# 0  29074.091797  12036639988  100.291016
# 1  29042.126953   6598366353   33.261719
# 2  29041.855469   7269806994    1.845703
# 3  29180.578125  13618163710  142.064453
# 4  29765.492188  17570561357  585.472657

# %%
market_df = market_df.drop(['Adj Close'], axis=1)
market_df.head()
# Out:
#         Date          Open          High           Low         Close  \
# 0 2023-08-04  29174.382813  29302.078125  28885.335938  29074.091797
# 1 2023-08-05  29075.388672  29102.464844  28957.796875  29042.126953
# 2 2023-08-06  29043.701172  29160.822266  28963.833984  29041.855469
# 3 2023-08-07  29038.513672  29244.281250  28724.140625  29180.578125
# 4 2023-08-08  29180.019531  30176.796875  29113.814453  29765.492188
#
#         Volume       Price
# 0  12036639988  100.291016
# 1   6598366353   33.261719
# 2   7269806994    1.845703
# 3  13618163710  142.064453
# 4  17570561357  585.472657

# %%
market_df.head(5)
# Out:
#         Date          Open          High           Low         Close  \
# 0 2023-08-04  29174.382813  29302.078125  28885.335938  29074.091797
# 1 2023-08-05  29075.388672  29102.464844  28957.796875  29042.126953
# 2 2023-08-06  29043.701172  29160.822266  28963.833984  29041.855469
# 3 2023-08-07  29038.513672  29244.281250  28724.140625  29180.578125
# 4 2023-08-08  29180.019531  30176.796875  29113.814453  29765.492188
#
#         Volume       Price
# 0  12036639988  100.291016
# 1   6598366353   33.261719
# 2   7269806994    1.845703
# 3  13618163710  142.064453
# 4  17570561357  585.472657

# %%
market_df.tail(5)
# Out:
#           Date          Open          High           Low         Close  \
# 362 2024-07-31  66201.273438  66810.210938  64532.046875  64619.250000
# 363 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 364 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 365 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 366 2024-08-04  60676.175781  61042.875000  60171.683594  60407.785156
#
#           Volume        Price
# 362  31292785994  1582.023438
# 363  40975554494   731.660156
# 364  43060875727  3938.433594
# 365  31753030589   734.714844
# 366  27502755840   268.390625

# %%
market_df.describe()
# Out:
#                       Date          Open          High           Low  \
# count                  367    367.000000    367.000000    367.000000
# mean   2024-02-03 00:00:00  48827.240213  49754.459953  47904.182343
# min    2023-08-04 00:00:00  25160.658203  25858.375000  24930.296875
# 25%    2023-11-03 12:00:00  34993.630860  35313.183594  34473.695312
# 50%    2024-02-03 00:00:00  44332.125000  45899.707031  43662.230469
# 75%    2024-05-04 12:00:00  64811.203125  66257.304688  63176.599610
# max    2024-08-04 00:00:00  73079.375000  73750.070313  71334.093750
# std                    NaN  15922.682412  16296.055980  15448.355626
#
#               Close        Volume        Price
# count    367.000000  3.670000e+02   367.000000
# mean   48912.975003  2.537049e+10   923.706127
# min    25162.654297  5.331173e+09     0.355469
# 25%    35043.363282  1.470112e+10   195.448243
# 50%    44957.968750  2.250600e+10   534.474609
# 75%    64849.404297  3.261844e+10  1302.714844
# ...

# %%
plt.Figure(figsize=(8,6))
sns.boxenplot(x='Price',data= market_df)
plt.title('Boxplot for Close Price')
plt.show()
